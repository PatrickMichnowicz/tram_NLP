# %% [markdown]
# # Getting a text sample for processing
#
# Wikipedia article about trams: https://en.wikipedia.org/wiki/Tram
#
# For the exercice, we keep 28 out of 42 pages; we are getting rid of references basically, as they are not relevant to the purpose of the exercice.

# %%
# Import PDF library to extract raw text
from pypdf import PdfReader

# %%
# Extract raw text from PDF and store inside an empty string

pdf_to_extract = PdfReader("./Tram_Wikipedia.pdf")

text=""

for page in pdf_to_extract.pages:
    text += page.extract_text()

#text

# %%
# Create an empty .txt file
# Save raw text inside the created .txt file
with open("tram_raw.txt", "w") as text_file:
    text_file.write(text)

# %% [markdown]
# # Text preprocessing
#
# Tokenization, lowercasing, lemmatization

# %%
# Assign the content of the raw text to a variable to be used and analyzed
raw_text = open("tram_raw.txt").read()

# %%
# Import necessary modules
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import regex as re

# %%
# Cut text into sentences
sentences = sent_tokenize(raw_text)

# Tokenize entire text
tokens = word_tokenize(raw_text)

# Unique tokens - entire documents
unique_tokens = set(tokens)

# Print the unique tokens + count of unique tokens
print(unique_tokens, "\n", len(unique_tokens))
# Out:
# {'302', 'Single', 'mec', 'ple', 'Being', 'invest', 'environments', 'Berne', 'infrequent', 'borders', 'trams', 'Measures', 'come', 'Gross-Lichterfelde', 'off', 'truncated', 'comunes', 'Medellín', 'tries', 'nondriven', 'accutram', 'except', 'studied', 'produced', '48', 'Bury', 'Passengers', 'Israel', 'engine', '£21', 'suitable', 'created', 'Galveston', 'December', 'Thomas', 'Padua', 'electricity', 'Mendoza', 'stamp', 'Stockholms', 'division', 'passenger-carrying', 'Then', 'morning', 'installa', 'unknown', 'ropelled', '18/42Map', 'purchased', '121', 'standard', 'so', 'Milwaukee', 'maxx=120', 'regenerative', 'having', 'emitting', 'gap', 'least', 'systems', 'goes', 'temporary', 'Halske', 'Initially', 'separate', 'Peterborough', '1804', 'Cincinnati', 'Hödl', 'Southern', 'Florence', 'fuel13/10/2024', 'Western', 'hard', 'appropriate', 'German', 'support', 'comprehensive', 'resume', 'railcars', 'deployed', 'fromSteam13/10/2024', 'colony', 'Midlands', 'segments', 'act', 'those', 'trolley', 'dismantled', 'rground', 'voyage', 'originally', 'style', 'il', 'talk', 'Highgate', '27', 'non-powered', 'Russian', '98', 'Diego', 'past', 'Universal', 'effort', 'true', 'classic', 'Overhead', 'continued', 'included', 'rush', 'preferred', '1860', 'September', 'zoom=333', 'short', 'sea', '13', '1923', 'Switzerland', 'city-wide', 'BVG', 'steep', 'newspape', 'tourist', 'CRRC', 'com', 'experimental', 'shock', 'price', 'fast', 'Entertainment', "''", 'peak', 'attraction', 'Bleecker', 'fares', 'Griffin', 'leads', 'needing', 'wider', '116', 'Matsuyama', 'partially', 'enabled', 'other', 'automobiles', 'report', 'susceptible', 'times', 'unsuccessful', 'e.g', 'V3A', 'D.C', 'horse', 'Stadtbahn', 'hypothesised', 'x/buurtspoorwegen', 'project', 'kept', 'operational', 'American', 'them', 'reduced', 'issue', 'extensive', 'along', 'shared', 'impractical', 's', 'The', 'current', 'production', '1836', 'roll', 'tracks', 'Jianying', '1:87', 'withdrawn', 'bega', '194.8', 'Orme', 'rubber', 'wereAfrica', 'Wharves', 'backlot', 'hazard', '1975', 'Northwest', 'Zealand', 'against', 'decommissioned', 'confusion', 'inner', 'trolley-', '21st', 'deta', ',', 'China', 'symbol', 'users', 'd-generation', 'frays', 'starting', 'Halifax', 'often', 'Brisbane', 'choice', 'door', 'higher', 'subject', 'Memorial', '1960', 'rail', '5/42Gross-Lichterfelde', '27/42Trackless', 'brass', 'sources', 'formation', 'winding', '64', 'Copenhagen', 'boiler', 'offering', 'almost', 'Lichterfelde', 'Tucson', 'comprise', 'Hall', 'solution', '£10', 'prime', 'Telford', 'radial', 'Niagara', 'second', 'Chin', 'Co', 'providing', 'Dresdner', 'lost', 'principal', 'pressure', 'sold', 'Isaac', 'Tatra', '117', 'head', 'floating', 'throug', '41', 'ienna', 'levers', 'web.archive.org/web/2005', 'opposed', 'makers', 'up-front', 'carrier', '2011', 'xdl=Sta', 'been', 'active', 'Los', '181', 'Pacific', 'monorail', 'like', 'now', 'Creation13/10/2024', 'website', 'Tramw', 'beenStatistics', 'described', '16/42A', 'ancient', 'full', 'economy', 'Seattle', 'easier', 'Port', 'Chicago', 'Transtech', 'Traction', 'South', 'island', 'rubber-tired', 'typically', '205', 'inserting', 'exam', 'switching', 'filled', 'stadtbahn', '5/5a', 'Hydrogen13/10/2024', 'previously', 'Human', 'point', 'eliminate', 'ptable', 'cash', '2024', 'improved', 'largestNorth', 'steel', 'loading', 'Tokyo', 'around', 'roads', '141', 'marketplace', '2007', 'Manufacturer', 'However', 'deemed', 'sign', 'ated', 'lower', 'all', 'points', 'y', 'warning', 'push', 'downhill', 'Steam', 'newspapers', 'mining', 'Basel', 'proposed', 'again', 'example', 'visual', 'Samarang', 'operated', 'universally', 'horsecar', '106-seat', 'paving', 'sends', 'dangerous', 'portion', 'east', 'obstructions', 'Amsterdam', 'Winnipeg', 'largely', 'India13/10/2024', 'hobby', 'once', 'V', 'any', '394', 'half', 'served', '10/42Siemens', 'experienced', 'explains', '1879', 'enough', '1828', '159', 'California', 'employed', '2009', 'actual', 'Maitland', 'in', 'Kinkisharyo', 'nd', '168', 'terrain', 'break', ...
#  3504

# %%
# Import Counter - class from a standard python library
from collections import Counter

# Convert the tokens into lowercase: lower_tokens
lower_tokens = [str.lower(t) for t in tokens]

# Create a Counter with the lowercase tokens
bow_text = Counter(lower_tokens)

# Print the 10 most common tokens
print(bow_text.most_common(20))
# Out:
# [('the', 800), (',', 763), ('in', 560), ('.', 532), ('and', 315), ('of', 304), ('tram', 259), ('a', 236), ('to', 217), ('[', 189), (']', 189), ('(', 182), (')', 182), ('was', 113), ('as', 107), ('trams', 102), ('on', 99), ('by', 93), ('system', 90), ('for', 89)]

# %%
# Import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Retain alphabetic words: alpha_only
alpha_only = [t for t in lower_tokens if t.isalpha()]

# Set English stop words to be removed
stop_words = set(stopwords.words("english"))

# Remove all stop words
stop_w_removed = [t for t in alpha_only if t not in stop_words]

# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Lemmatize all tokens into a new list: lemmatized
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in stop_w_removed]

# Create the bag-of-words: bow
bow_stop_w_removed = Counter(lemmatized)

# Print the 10 most common tokens
print(bow_stop_w_removed.most_common(20))
# Out:
# [('tram', 361), ('system', 173), ('line', 98), ('tramway', 84), ('rail', 82), ('city', 82), ('streetcar', 63), ('track', 55), ('km', 54), ('mi', 53), ('cable', 53), ('network', 44), ('first', 44), ('new', 44), ('railway', 43), ('car', 43), ('light', 41), ('service', 41), ('electric', 39), ('used', 38)]
