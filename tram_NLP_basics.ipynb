# %% [markdown]
# # Text preprocessing

# %%
# Assign the content of the raw text to a variable to be used and analyzed
raw_text = open("tram_raw.txt").read()

# %%
# Import necessary modules
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import regex as re

# %% [markdown]
# ### Sentences and tokens

# %%
# Cut text into sentences
sentences = sent_tokenize(raw_text)

# Tokenize entire text
tokens = word_tokenize(raw_text)

# Unique tokens - entire documents
unique_tokens = set(tokens)

# Print the unique tokens + count of unique tokens
print(unique_tokens, "\n", len(unique_tokens))
# Out:
# {'2022In', 'manufac', 'moderate', '1987.There', 'PKTS/Metrovagonmash316', 'deployed', 'horsecar', '51', 'Perth', 'non-powered', 'architect', 'London', '1894', '85', 'Jerusalem', 'slot', 'fleet', 'Bombardier', '161', 'Flemish', 'petrol', 'ox-drawn', 'Englan', 'Breaks', 'Pittsburgh', 'winter', 'pe', 'it', 'efficiently', 'hauled', 'regenerative', 'Society', 'temporary', 'centuries', 'portmanteau', 'driven', 'systems13/10/2024', 'oper', '1957', 'here', 'postcode_n=1012', '102', 'held', 'nautical', '131', 'transport', 'goods', '640', 'American', 'significantly', 'derivation', 'believe', 'advising', 'rights-of-', 'allow', '1897–1908', 'China', '105', 'simultaneous', 'Medellín', 'Kingdom13/10/2024', 'environments', 'plateways', 'Bergen', 'Góra', '72/73', 'housed', '2008', 'Great', 'route', 'send', 'sometimes', 'interest', 'gauntlet', 'pairs', 'epoxy', 'better', 'Romania', 'pulleys', '38', 'Vehicles', 'inner', 'internal', 'fairly', 'Vancouver', 'unreliable', '1828', 'Convict', 'Russian', 'inaccessible', 'hour', 'delivering', 'Hamilton', 'presented', 'discontinued', 'T', 'subsidiary', 'cables', 'if', '62', 'local', 'longest-lasting', '1980s', 'Annes', 'Étienne', 'Urban', 'permanent', 'Clifton', 'Exposition', '129', 'Etymologists', 'Street', 'revival', 'began', 'those', 'City', 'flicking', 'needing', 'modern', 'listed', 'At', 'Route-setting', '1900', 'preserved', 'mid-sized', 'Trolley', 'trackless', 'continues', '4', 'help', '370', 'since', 'Vélocio', '1884', 'Turin', 'holds', '1917', 'reported', 'mile', 'Dresdner', 'differences', '152', 'den', 're-introduced', 'ranged', 'wider', 'growing', 'famous', '106', '9,705', 'wheels', "'grounded'—not", 'arises', 'Streetcars', 'political', '5/5a', 'postcode_a=JS', 'independence', 'psychological', 'ancient', 'Munich', 'elsewhere', 'metro', 'segmented', 'Africa', 'joined', '825', 'installing', '171', 'Griffin', 'never', 'Doncaster', 'associated', 'existed', 'mass', 'double-decker', 'former', 'bicycles', 'did', 'lasted', 'Beamish', '133', 'xsl=Layout', 'blacksmith', 'minimise', 'doubling', 'Cologne', 'overall', 'citywide', 'double-track', 'carriages', 'government', 'Avenue', 'Ultra', 'Engineer', 'grooves', 'some', 'generally', 'Mekarski', 'Neath', 'yon', 'Kalgoorlie', 'low', 'accompanied', '201', 'Taipei', 'wire', 'correct', 'levels', 'plastic', 'Soviet', 'powered', 'result', 'makers', 'Flexity', 'fact', 'infrequent', 'painting', 'stops', '1905', '184', 'Puerto', 'solved', 'Most', 'Flexit', 'Orme', 'whilst', 'same', 'solid', 'Lopburi', 'improvement', 'options', 'Helsinki', 'st', 'dependency', 'ideal', 'European', 'Short', 'stand', 'settlements', '1978', 'includes', 'people-mover', 'journal', 'need', 'decommissioned', 'cancelled', 'Pont', 'enables', 'of', 'tractors', 'Tramlink', 'comunes', 'Taylor', 'assumed', 'early', '122', '2017', 'articulated', 'long-term', '11', 'extensive', 'should', 'Car', 'carry', 'laid', 'Bay', 'mult', 'susceptible', 'issued', 'company', '690', 'Stadtbahn', 'feed', 'Denmark', '1880', 'Cotton', '1852', 'Wright', '191.6', 'ropelled', 'vary', 'labor', 'although', 'Isle', 'Italy', 'examples', 'pen', 'zenith', 'particularlyCross-border', '``', 'tendency', '1885', 'Hemisphere', 'salons', 'refer', 'ficulties', 'called', 'dozen', 'unde', 'studying', 'mines', 'ff', 'April', 'Measures', 'tries', 'needed', 'coast', 'tentative', 'Escarpment', '1840', 'Christchurch', 'Centre', 'Basel', '//adres.asp4all.nl/asp/get.as', 'Q-Car', 'Pirotsky', 'doubled', '5.0', 'UK', 'multiple-unit', 'electric', 'hubs', 'y_coord=487379', '400', 'come', 'backlot', 'situations', 'cent', '1901', 'true', 'gauges', 'shared', 'fast', 'vehicles', 'E2', 'Colombia', 'Overhead', 'high-speed', 'whole', 'Switzerland', 'exceptions', 'east', '28', 'Another', 'exhibit', 'induction', 'Railway', 'Parliament', 'similar', 'tech', 'https', '87', 'legally', 'Łódź', 'served', 'cognate', 'types', 'obstruction', 'demonstration', 'ptable', 'build', 'may', 'break', 'relic', 'bega', 'DHA', 'restrain', 'utilized', 'conduit', 'taken', 'R ...
#  3504

# %% [markdown]
# ### Creating a bag-of-words including stop-words

# %%
# Import Counter - class from a standard python library
from collections import Counter

# Convert the tokens into lowercase: lower_tokens
lower_tokens = [str.lower(t) for t in tokens]

# Create a Counter with the lowercase tokens
bow_text = Counter(lower_tokens)

# Print the 20 most common tokens
print(bow_text.most_common(20))
# Out:
# [('the', 800), (',', 763), ('in', 560), ('.', 532), ('and', 315), ('of', 304), ('tram', 259), ('a', 236), ('to', 217), ('[', 189), (']', 189), ('(', 182), (')', 182), ('was', 113), ('as', 107), ('trams', 102), ('on', 99), ('by', 93), ('system', 90), ('for', 89)]

# %% [markdown]
# ### Excluding stop words

# %%
# Import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Retain alphabetic words
alpha_only = [t for t in lower_tokens if t.isalpha()]

# Set English stop words to be removed
stop_words = set(stopwords.words("english"))

# Remove all stop-words
stop_w_removed = [t for t in alpha_only if t not in stop_words]

# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Lemmatize all tokens into a new list
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in stop_w_removed]

# Create the bag-of-words without stop-words
bow_stop_w_removed = Counter(lemmatized)

# Print the 20 most common tokens
print(bow_stop_w_removed.most_common(20))
# Out:
# [('tram', 361), ('system', 173), ('line', 98), ('tramway', 84), ('rail', 82), ('city', 82), ('streetcar', 63), ('track', 55), ('km', 54), ('mi', 53), ('cable', 53), ('network', 44), ('first', 44), ('new', 44), ('railway', 43), ('car', 43), ('light', 41), ('service', 41), ('electric', 39), ('used', 38)]
