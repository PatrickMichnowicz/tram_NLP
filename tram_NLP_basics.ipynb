# %% [markdown]
# # Text preprocessing

# %%
# Assign the content of the raw text to a variable to be used and analyzed
raw_text = open("tram_raw.txt").read()

# %%
# Import necessary modules
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import regex as re

# %% [markdown]
# ### Sentences and tokens

# %%
# Cut text into sentences
sentences = sent_tokenize(raw_text)

# Tokenize entire text
tokens = word_tokenize(raw_text)

# Unique tokens - entire documents
unique_tokens = set(tokens)

# Print the unique tokens + count of unique tokens
print(unique_tokens, "\n", len(unique_tokens))
# Out:
# {'situations', 'computer', 'trials', 'lowered', 'require', 'notable', 'dropped', 'series', 'Brazil13/10/2024', 'trolley-', 'run', '89', 'grab', 'improved', 'hypothesised', '148.3', 'long', 'tight', 'HTM', 'progress', 'flicking', 'reduced', 'version', 'national', 'weight', 'antiquated', 'inery', '1896', 'Soviet', 'dual', 'Africa', 'Box', 'Carrollton', 'Handcar', 'insufficient', 'seen', 'c.', 'moderate', 'Matsuyama', 'propelling', 'provision', '44', 'DHA', 'tric', 'restarted', 'drive', 'e', 'favoring', 'swapping', 'provided', 'confused', 'enter', 'smoother', 'northern', 'Alexandria', 'carts', 'Zealand', 'urban', 'boarded', 'intern', '1909', 'Bucharest', 'Stage', 'Another', 'brother', 'down', 'edded', 'enables', 'South', 'described', 'Alabama', 'kilometer', "'point", 'That', 'battery-operated', 'sliding', 'suburban', 'Transit', 'beams', 'Each', 'Little', 'trolleycar', '250', 'defunct', '172', 'loads', '127.7', 'not', '86', '1898', '857', 'mining', 'condensers', 'replaces', 'Dalian', '1987.There', 'beachside', 'grow', 'representation', 'tries', 'woo', '1700s', 'vault', 'each', 'minor', 'startedNew', '127', 'family', '93', 'internal', 'Maitland', 'ally', 'switches', 'fect', 'Brixton', 'Temple', 'travel', 'figure', 'counterpart', 'Car', 'advising', 'already', 'emitting', '2011', 'Low-floor', 'favour', 'records', 'displays', 'prefabricated', 'driven', 'concealed', '1971', 'Texas', '1024231501/http', 'thus', 'navigate', 'individual', 'trackway', 'transmission', '148', 'represents', '58', 'landslip', 'Seine', 'freight', 'actually', 'hazardous', 'foreground', 'Florence', 'early', 'congestion', 'railroad', '200', 'recent', 'developers', 'assembly', '130', 'Railway', 'like', 'Estonia', 'mixed', 'from', 'commuter', '1901', 'Geelong', '151', 'drawback', '1908', 'Qingdao', 'nearby', 'studied', 'Debate', 'renaissance', '9-sectioned', '1917', 'oper', 'Kingdom13/10/2024', 'Douglas', 'energy', 'old', 'heavy', 'iron', 'Tokyo', '189', 'stage', 'battery-powered', 'men', 'found', 'changes', 'Tria', 'ACT', 'sections', 'drawn', 'Washington', 'political', 'ring', 'connected', 'collection', 'labor', 'wagon', 'repaired', 'tunnels', '1887', '(', 'causing', '7/42Melbourne', 'alleviated', 'brakes', 'Rail', 'phase', 'usin', 'Boston', 'de', 'rtant', 'Tramways', 'oad', 'Ultra', 'mid-20th', 'fares', 'crossbeam', 'functional', 'York', 'arly', 'bicycles', 'approach', 'Isle', 'batteries', 'train', 'Maastricht', 'tions', '48', 'placed', '142', 'improvement', '199', 'Llandudno', 'infrastructure', 'sources', '47', 'Port', 'Being', 'Regina', 'onboard', 'handful', 'election', 'Union', '1,460', 'Citadis', 'refers', 'Alphonse', 'theory', 'fast', 'ancient', 'regenerative', '16', '305', 'appeared', 'inaccessible', 'October', ';', 'left', 'but', 'damage', 'xsl=Layout', 'mm', 'Angeles', 'recorded', 'Montreal', '136', '122', 'new', 'charge', 'Bay', 'supply', 'Peg-Le', 'Bordeaux', 'true', 'Brighton', 'innovation', 'end', '43', '394', 'patented', 'low-powered', 'subject', '113', 'bow', 'installa', 'uphill', 'accompanied', 'fairly', 'Colombia', 'strictly', 'right-of-way', 'Empire', 'Stockholm', 'interco', '133.1', 'inaugurated', 'does', 'eliminate', 'flexible', 'wire', 'into', 'Launceston', 'automobile-style', 'includ', 'sustained', 'certainly', '3', 'vendors', '1983', 'agglomeration', '19/-', 'also', 'short', 'unknown', 'rush', 'Transport', 'Short', 'Góra', 'W', 'equivalent', 'faded', 'allowed', '88.5', '101', 'clothing', 'rebuilt', 'fringe', 'Boelelaan/VU', '20.4', 'tramcars', '183', '1978', 'chief', 'referring', 'Saskatoon', 'higher', 'OHL', 'units', 'partly', '1939', 'grade-separa', '1:43,5', '1869', 'point', '80', '170', 'send', 'fatalities', 'es', 'oppos', 'derailing', 'refer', 'third-rail', 'Singapore', 'Anne', 'point-setting', 'incorrect', 'Fran', 'motor', '99', 'would', 'majority', 'increasingly', 'environments', '4/42The', 'France', 'Seattle', 'Victor', '–', 'immediately', 'Anoth', 'American', '1900Horses', 'godfather', '1881', 'Trieste–Opicina', 'up-front', 'resulted' ...
#  3504

# %% [markdown]
# ### Creating a bag-of-words including stop-words

# %%
# Import Counter - class from a standard python library
from collections import Counter

# Convert the tokens into lowercase: lower_tokens
lower_tokens = [str.lower(t) for t in tokens]

# Create a Counter with the lowercase tokens
bow_text = Counter(lower_tokens)

# Print the 20 most common tokens
print(bow_text.most_common(20))
# Out:
# [('the', 800), (',', 763), ('in', 560), ('.', 532), ('and', 315), ('of', 304), ('tram', 259), ('a', 236), ('to', 217), ('[', 189), (']', 189), ('(', 182), (')', 182), ('was', 113), ('as', 107), ('trams', 102), ('on', 99), ('by', 93), ('system', 90), ('for', 89)]

# %% [markdown]
# ### Excluding stop-words

# %%
# Import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Retain alphabetic words
alpha_only = [t for t in lower_tokens if t.isalpha()]

# Set English stop words to be removed
stop_words = set(stopwords.words("english"))

# Remove all stop-words
stop_w_removed = [t for t in alpha_only if t not in stop_words]

# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Lemmatize all tokens into a new list
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in stop_w_removed]

# Create the bag-of-words without stop-words
bow_stop_w_removed = Counter(lemmatized)

# Print the 20 most common tokens
print(bow_stop_w_removed.most_common(20))
# Out:
# [('tram', 361), ('system', 173), ('line', 98), ('tramway', 84), ('rail', 82), ('city', 82), ('streetcar', 63), ('track', 55), ('km', 54), ('mi', 53), ('cable', 53), ('network', 44), ('first', 44), ('new', 44), ('railway', 43), ('car', 43), ('light', 41), ('service', 41), ('electric', 39), ('used', 38)]
